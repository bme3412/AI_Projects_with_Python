# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os 
from datetime import datetime

# %%
def scrape_nba_data_team_boxscores(team, season):
    # HTML content
    url = f'https://www.basketball-reference.com/teams/{team}/{season}_games.html'
    response = requests.get(url)
    
 
    # Create a BeautifulSoup object
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the table element
    table = soup.find('table', class_='sortable stats_table', id='games')
    
    if table is None:
        print(f"No table found for team {team} in season {season}")
        return None
    
    # Find all the rows in the table body
    rows = table.tbody.find_all('tr')
    
    # Create empty lists to store the extracted data
    game_numbers = []
    dates = []
    visitor_neutrals = []
    visitor_pts_list = []
    home_neutrals = []
    home_pts_list = []
    box_score_links = []
    arenas = []
    
    # Iterate over each row and extract the desired information
    for row in rows:
        game_num = row.find('th', {'data-stat': 'g'})
        if game_num == "G":
            continue
        
        date_element = row.find('td', {'data-stat': 'date_game'})
        date = date_element.text.strip() if date_element else ''
        
        # Skip/continue if the value in the "Date" column is equal to "Date"
        
        visitor_neutral_element = row.find('td', {'data-stat': 'opp_name'})
        visitor_neutral = visitor_neutral_element.text.strip() if visitor_neutral_element else ''
        
        visitor_pts_element = row.find('td', {'data-stat': 'opp_pts'})
        visitor_pts = visitor_pts_element.text.strip() if visitor_pts_element else ''
        
        home_neutral = team
        
        home_pts_element = row.find('td', {'data-stat': 'pts'})
        home_pts = home_pts_element.text.strip() if home_pts_element else ''
        
        box_score_link_element = row.find('td', {'data-stat': 'box_score_text'})
        box_score_link = 'https://www.basketball-reference.com' + box_score_link_element.a['href'] if box_score_link_element and box_score_link_element.a else ''
        
        game_location_element = row.find('td', {'data-stat': 'game_location'})
        arena = 'Home' if game_location_element and game_location_element.text.strip() == '@' else 'Away'
        
        game_numbers.append(game_num.text.strip() if game_num else '')
        dates.append(date)
        visitor_neutrals.append(visitor_neutral)
        visitor_pts_list.append(visitor_pts)
        home_neutrals.append(home_neutral)
        home_pts_list.append(home_pts)
        box_score_links.append(box_score_link)
        arenas.append(arena)
    
    # Scrape data from each box score link and save as separate CSV files
    for i, link in enumerate(box_score_links):
        # Skip if the game number is "G"
        if game_numbers[i] == "G":
            continue
    
        box_score_response = requests.get(link)
        box_score_soup = BeautifulSoup(box_score_response.text, 'html.parser')
    
        # Find the table element with class "sortable stats_table" and an id containing "game-basic"
        stats_table = box_score_soup.find('table', class_='sortable stats_table', id=lambda x: x and f'{team}-game-basic' in x)
    
        if stats_table:
            # Extract the team abbreviation from the id attribute
            team_abbr = stats_table['id'].split('-')[1].upper()
    
            # Check if the team abbreviation matches the desired team
            if team_abbr != team:
                print(f"Skipping box score for {link} as it belongs to a different team ({team_abbr})")
                continue
    
            # Find all the rows in the table body
            stats_rows = stats_table.tbody.find_all('tr')
    
            # Extract the desired information from each row
            basic_stats_data = []
            for row in stats_rows:
                player = row.find('th', {'data-stat': 'player'})
                player = player.text.strip() if player else ''
    
                mp = row.find('td', {'data-stat': 'mp'})
                mp = mp.text.strip() if mp else ''
    
                fg = row.find('td', {'data-stat': 'fg'})
                fg = fg.text.strip() if fg else ''
    
                fga = row.find('td', {'data-stat': 'fga'})
                fga = fga.text.strip() if fga else ''
    
                fg_pct = row.find('td', {'data-stat': 'fg_pct'})
                fg_pct = fg_pct.text.strip() if fg_pct else ''
    
                fg3 = row.find('td', {'data-stat': 'fg3'})
                fg3 = fg3.text.strip() if fg3 else ''
    
                fg3a = row.find('td', {'data-stat': 'fg3a'})
                fg3a = fg3a.text.strip() if fg3a else ''
    
                fg3_pct = row.find('td', {'data-stat': 'fg3_pct'})
                fg3_pct = fg3_pct.text.strip() if fg3_pct else ''
    
                ft = row.find('td', {'data-stat': 'ft'})
                ft = ft.text.strip() if ft else ''
    
                fta = row.find('td', {'data-stat': 'fta'})
                fta = fta.text.strip() if fta else ''
    
                ft_pct = row.find('td', {'data-stat': 'ft_pct'})
                ft_pct = ft_pct.text.strip() if ft_pct else ''
    
                orb = row.find('td', {'data-stat': 'orb'})
                orb = orb.text.strip() if orb else ''
    
                drb = row.find('td', {'data-stat': 'drb'})
                drb = drb.text.strip() if drb else ''
    
                trb = row.find('td', {'data-stat': 'trb'})
                trb = trb.text.strip() if trb else ''
    
                ast = row.find('td', {'data-stat': 'ast'})
                ast = ast.text.strip() if ast else ''
    
                stl = row.find('td', {'data-stat': 'stl'})
                stl = stl.text.strip() if stl else ''
    
                blk = row.find('td', {'data-stat': 'blk'})
                blk = blk.text.strip() if blk else ''
    
                tov = row.find('td', {'data-stat': 'tov'})
                tov = tov.text.strip() if tov else ''
    
                pf = row.find('td', {'data-stat': 'pf'})
                pf = pf.text.strip() if pf else ''
    
                pts = row.find('td', {'data-stat': 'pts'})
                pts = pts.text.strip() if pts else ''
    
                plus_minus = row.find('td', {'data-stat': 'plus_minus'})
                plus_minus = plus_minus.text.strip() if plus_minus else ''
    
                basic_stats_data.append([player, mp, fg, fga, fg_pct, fg3, fg3a, fg3_pct, ft, fta, ft_pct, orb, drb, trb, ast, stl, blk, tov, pf, pts, plus_minus])
    
        else:
            print(f"No basic stats table found for {link}")
            continue
    
        # Find the table element with class "sortable stats_table" and the specific id
        adv_stats_table = box_score_soup.find('table', class_='sortable stats_table', id=lambda x: x and f'{team}-game-advanced' in x)
    
        if adv_stats_table:
            # Extract the team abbreviation from the id attribute
            adv_team_abbr = adv_stats_table['id'].split('-')[1].upper()
    
            # Check if the team abbreviation matches the desired team
            if adv_team_abbr != team:
                print(f"Skipping advanced stats table for {link} as it belongs to a different team ({adv_team_abbr})")
                continue
    
            # Find all the rows in the table body
            adv_stats_rows = adv_stats_table.tbody.find_all('tr')
    
            # Extract the desired information from each row
            adv_stats_data = []
            for row in adv_stats_rows:
                player = row.find('th', {'data-stat': 'player'})
                player = player.text.strip() if player else ''
    
                mp = row.find('td', {'data-stat': 'mp'})
                mp = mp.text.strip() if mp else ''
    
                ts_pct = row.find('td', {'data-stat': 'ts_pct'})
                ts_pct = ts_pct.text.strip() if ts_pct else ''
    
                efg_pct = row.find('td', {'data-stat': 'efg_pct'})
                efg_pct = efg_pct.text.strip() if efg_pct else ''
    
                fg3a_per_fga_pct = row.find('td', {'data-stat': 'fg3a_per_fga_pct'})
                fg3a_per_fga_pct = fg3a_per_fga_pct.text.strip() if fg3a_per_fga_pct else ''
    
                fta_per_fga_pct = row.find('td', {'data-stat': 'fta_per_fga_pct'})
                fta_per_fga_pct = fta_per_fga_pct.text.strip() if fta_per_fga_pct else ''
    
                orb_pct = row.find('td', {'data-stat': 'orb_pct'})
                orb_pct = orb_pct.text.strip() if orb_pct else ''
    
                drb_pct = row.find('td', {'data-stat': 'drb_pct'})
                drb_pct = drb_pct.text.strip() if drb_pct else ''
    
                trb_pct = row.find('td', {'data-stat': 'trb_pct'})
                trb_pct = trb_pct.text.strip() if trb_pct else ''
    
                ast_pct = row.find('td', {'data-stat': 'ast_pct'})
                ast_pct = ast_pct.text.strip() if ast_pct else ''
    
                stl_pct = row.find('td', {'data-stat': 'stl_pct'})
                stl_pct = stl_pct.text.strip() if stl_pct else ''
    
                blk_pct = row.find('td', {'data-stat': 'blk_pct'})
                blk_pct = blk_pct.text.strip() if blk_pct else ''
    
                tov_pct = row.find('td', {'data-stat': 'tov_pct'})
                tov_pct = tov_pct.text.strip() if tov_pct else ''
    
                usg_pct = row.find('td', {'data-stat': 'usg_pct'})
                usg_pct = usg_pct.text.strip() if usg_pct else ''
    
                off_rtg = row.find('td', {'data-stat': 'off_rtg'})
                off_rtg = off_rtg.text.strip() if off_rtg else ''
    
                def_rtg = row.find('td', {'data-stat': 'def_rtg'})
                def_rtg = def_rtg.text.strip() if def_rtg else ''
    
                bpm = row.find('td', {'data-stat': 'bpm'})
                bpm = bpm.text.strip() if bpm else ''
    
                adv_stats_data.append([player, mp, ts_pct, efg_pct, fg3a_per_fga_pct, fta_per_fga_pct, orb_pct, drb_pct, trb_pct, ast_pct, stl_pct, blk_pct, tov_pct, usg_pct, off_rtg, def_rtg, bpm])
    
        else:
            print(f"No advanced stats table found for {link}")
            continue
    
        # Combine the basic and advanced stats data based on matching player names
        combined_stats_data = []
        for basic_stats in basic_stats_data:
            player = basic_stats[0]
            for adv_stats in adv_stats_data:
                if adv_stats[0] == player:
                    combined_stats = [game_numbers[i], team_abbr] + basic_stats + adv_stats[1:]
                    combined_stats_data.append(combined_stats)
                    break
    
        # Create a DataFrame for the combined stats data
        columns = ['Game_number', 'Team', 'Player', 'MP_basic', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', '+/-', 'MP_adv', 'TS%', 'eFG%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'ORtg', 'DRtg', 'BPM']
        df_stats = pd.DataFrame(combined_stats_data, columns=columns)
    
        # Create the directory structure if it doesn't exist
        directory = f"{season}/{team}"
        os.makedirs(directory, exist_ok=True)
    
        # Convert the date to "mm/dd/YYYY" format
        date_obj = datetime.strptime(dates[i], '%a, %b %d, %Y')
        mm_dd_YYYY = date_obj.strftime('%m_%d_%Y')
        
        # Generate a unique filename for each game with the desired format
        filename = f"{directory}/{game_numbers[i]}_{mm_dd_YYYY}_{team_abbr}_vs_{visitor_neutrals[i]}.csv"
        
        # Save the DataFrame to a CSV file with the unique filename
        df_stats.to_csv(filename, index=False)
        
        print(f"DataFrame saved to {filename}")

# %%
# NBA team abbreviations
#nba_teams = ['ATL', 'BOS', 'BRK', 'CHI', 'CHO', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS']

# Iterate over the years and teams
#for year in range(2018, 2025):
    #for team in nba_teams:
        #scrape_nba_data_team_boxscores(team, year)
# Out:
# DataFrame saved to 2018/ATL/1_10_18_2017_ATL_vs_Dallas Mavericks.csv
# DataFrame saved to 2018/ATL/2_10_20_2017_ATL_vs_Charlotte Hornets.csv
# DataFrame saved to 2018/ATL/3_10_22_2017_ATL_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/ATL/4_10_23_2017_ATL_vs_Miami Heat.csv
# DataFrame saved to 2018/ATL/5_10_26_2017_ATL_vs_Chicago Bulls.csv
# DataFrame saved to 2018/ATL/6_10_27_2017_ATL_vs_Denver Nuggets.csv
# DataFrame saved to 2018/ATL/7_10_29_2017_ATL_vs_Milwaukee Bucks.csv
# DataFrame saved to 2018/ATL/8_11_01_2017_ATL_vs_Philadelphia 76ers.csv
# DataFrame saved to 2018/ATL/9_11_03_2017_ATL_vs_Houston Rockets.csv
# DataFrame saved to 2018/ATL/10_11_05_2017_ATL_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/ATL/11_11_06_2017_ATL_vs_Boston Celtics.csv
# DataFrame saved to 2018/ATL/12_11_10_2017_ATL_vs_Detroit Pistons.csv
# DataFrame saved to 2018/ATL/13_11_11_2017_ATL_vs_Washington Wizards.csv
# DataFrame saved to 2018/ATL/14_11_13_2017_ATL_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/ATL/15_11_15_2017_ATL_vs_Sacramento Kings.csv
# DataFrame saved to 2018/ATL/16_11_18_2017_ATL_vs_Boston Celtics.csv
# DataFrame saved to 2018/ATL/17_11_20_2017_ATL_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/ATL/18_11_22_2017_ATL_vs_Los Angeles Clippers.csv
# DataFrame saved to 2018/ATL/19_11_24_2017_ATL_vs_New York Knicks.csv
# DataFrame saved to 2018/ATL/20_11_25_2017_ATL_vs_Toronto Raptors.csv
# DataFrame saved to 2018/ATL/21_11_30_2017_ATL_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/ATL/22_12_02_2017_ATL_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/ATL/23_12_04_2017_ATL_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/ATL/24_12_06_2017_ATL_vs_Orlando Magic.csv
# DataFrame saved to 2018/ATL/25_12_09_2017_ATL_vs_Orlando Magic.csv
# DataFrame saved to 2018/ATL/26_12_10_2017_ATL_vs_New York Knicks.csv
# DataFrame saved to 2018/ATL/27_12_12_2017_ATL_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/ATL/28_12_14_2017_ATL_vs_Detroit Pistons.csv
# DataFrame saved to 2018/ATL/29_12_15_2017_ATL_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/ATL/30_12_18_2017_ATL_vs_Miami Heat.csv
# DataFrame saved to 2018/ATL/31_12_20_2017_ATL_vs_Indiana Pacers.csv
# DataFrame saved to 2018/ATL/32_12_22_2017_ATL_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018
vs_Atlanta Hawks.csv
# DataFrame saved to 2018/BOS/81_04_10_2018_BOS_vs_Washington Wizards.csv
# DataFrame saved to 2018/BOS/82_04_11_2018_BOS_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/BRK/1_10_18_2017_BRK_vs_Indiana Pacers.csv
# DataFrame saved to 2018/BRK/2_10_20_2017_BRK_vs_Orlando Magic.csv
# DataFrame saved to 2018/BRK/3_10_22_2017_BRK_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/BRK/4_10_24_2017_BRK_vs_Orlando Magic.csv
# DataFrame saved to 2018/BRK/5_10_25_2017_BRK_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/BRK/6_10_27_2017_BRK_vs_New York Knicks.csv
# DataFrame saved to 2018/BRK/7_10_29_2017_BRK_vs_Denver Nuggets.csv
# DataFrame saved to 2018/BRK/8_10_31_2017_BRK_vs_Phoenix Suns.csv
# DataFrame saved to 2018/BRK/9_11_03_2017_BRK_vs_Los Angeles Lakers.csv
# DataFrame saved to 2018/BRK/10_11_06_2017_BRK_vs_Phoenix Suns.csv
# DataFrame saved to 2018/BRK/11_11_07_2017_BRK_vs_Denver Nuggets.csv
# DataFrame saved to 2018/BRK/12_11_10_2017_BRK_vs_Portland Trail Blazers.csv
# DataFrame saved to 2018/BRK/13_11_11_2017_BRK_vs_Utah Jazz.csv
# DataFrame saved to 2018/BRK/14_11_14_2017_BRK_vs_Boston Celtics.csv
# DataFrame saved to 2018/BRK/15_11_17_2017_BRK_vs_Utah Jazz.csv
# DataFrame saved to 2018/BRK/16_11_19_2017_BRK_vs_Golden State Warriors.csv
# DataFrame saved to 2018/BRK/17_11_22_2017_BRK_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/BRK/18_11_24_2017_BRK_vs_Portland Trail Blazers.csv
# DataFrame saved to 2018/BRK/19_11_26_2017_BRK_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/BRK/20_11_27_2017_BRK_vs_Houston Rockets.csv
# DataFrame saved to 2018/BRK/21_11_29_2017_BRK_vs_Dallas Mavericks.csv
# DataFrame saved to 2018/BRK/22_12_02_2017_BRK_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/BRK/23_12_04_2017_BRK_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/BRK/24_12_07_2017_BRK_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018/BRK/25_12_09_2017_BRK_vs_Miami Heat.csv
# DataFrame saved to 2018/BRK/26_12_12_2017_BRK_vs_Washington Wizards.csv
# DataFrame saved to 2018/BRK/27_12_14_2017_BRK_vs_New York Knicks.csv
# DataFrame saved to 2018/BRK/28_12_15_2017_BRK_vs_Toronto Raptors.csv
# DataFrame saved to 2018/BRK/29_12_17_2017_BRK_vs_Indiana Pacers.csv
# DataFrame saved to 2018/BRK/30_12_20_2017_BRK_vs_Sacramento Kings.csv
# DataFrame saved to 2018/BRK/31_12_22_2017_BRK_vs_Washington Wizards.csv
# DataFrame saved to 2018/BRK/32_12_23_2017_BRK_vs_Indiana Pacers.csv
# DataFrame saved to 2018/BRK/33_12_26_2017_BRK_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/BRK/34_12_27_2017_BRK_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/BRK/35_12_29_2017_BRK_vs_Miami Heat.csv
# DataFrame saved to 2018/BRK/36_12_31_2017_BRK_vs_Boston Celtics.csv
# DataFrame saved to 2018/BRK/37_01_01_2018_BRK_vs_Orlando Magic.csv
# DataFrame saved to 2018/BRK/38_01_03_2018_BRK_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2018
vs_San Antonio Spurs.csv
# DataFrame saved to 2018/CLE/47_01_26_2018_CLE_vs_Indiana Pacers.csv
# DataFrame saved to 2018/CLE/48_01_28_2018_CLE_vs_Detroit Pistons.csv
# DataFrame saved to 2018/CLE/49_01_30_2018_CLE_vs_Detroit Pistons.csv
# DataFrame saved to 2018/CLE/50_01_31_2018_CLE_vs_Miami Heat.csv
# DataFrame saved to 2018/CLE/51_02_03_2018_CLE_vs_Houston Rockets.csv
# DataFrame saved to 2018/CLE/52_02_06_2018_CLE_vs_Orlando Magic.csv
# DataFrame saved to 2018/CLE/53_02_07_2018_CLE_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2018/CLE/54_02_09_2018_CLE_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/CLE/55_02_11_2018_CLE_vs_Boston Celtics.csv
# DataFrame saved to 2018/CLE/56_02_13_2018_CLE_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018/CLE/57_02_22_2018_CLE_vs_Washington Wizards.csv
# DataFrame saved to 2018/CLE/58_02_23_2018_CLE_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/CLE/59_02_25_2018_CLE_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/CLE/60_02_27_2018_CLE_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/CLE/61_03_01_2018_CLE_vs_Philadelphia 76ers.csv
# DataFrame saved to 2018/CLE/62_03_03_2018_CLE_vs_Denver Nuggets.csv
# DataFrame saved to 2018/CLE/63_03_05_2018_CLE_vs_Detroit Pistons.csv
# DataFrame saved to 2018/CLE/64_03_07_2018_CLE_vs_Denver Nuggets.csv
# DataFrame saved to 2018/CLE/65_03_09_2018_CLE_vs_Los Angeles Clippers.csv
# DataFrame saved to 2018/CLE/66_03_11_2018_CLE_vs_Los Angeles Lakers.csv
# DataFrame saved to 2018/CLE/67_03_13_2018_CLE_vs_Phoenix Suns.csv
# DataFrame saved to 2018/CLE/68_03_15_2018_CLE_vs_Portland Trail Blazers.csv
# DataFrame saved to 2018/CLE/69_03_17_2018_CLE_vs_Chicago Bulls.csv
# DataFrame saved to 2018/CLE/70_03_19_2018_CLE_vs_Milwaukee Bucks.csv
# DataFrame saved to 2018/CLE/71_03_21_2018_CLE_vs_Toronto Raptors.csv
# DataFrame saved to 2018/CLE/72_03_23_2018_CLE_vs_Phoenix Suns.csv
# DataFrame saved to 2018/CLE/73_03_25_2018_CLE_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/CLE/74_03_27_2018_CLE_vs_Miami Heat.csv
# DataFrame saved to 2018/CLE/75_03_28_2018_CLE_vs_Charlotte Hornets.csv
# DataFrame saved to 2018/CLE/76_03_30_2018_CLE_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/CLE/77_04_01_2018_CLE_vs_Dallas Mavericks.csv
# DataFrame saved to 2018/CLE/78_04_03_2018_CLE_vs_Toronto Raptors.csv
# DataFrame saved to 2018/CLE/79_04_05_2018_CLE_vs_Washington Wizards.csv
# DataFrame saved to 2018/CLE/80_04_06_2018_CLE_vs_Philadelphia 76ers.csv
# DataFrame saved to 2018/CLE/81_04_09_2018_CLE_vs_New York Knicks.csv
# DataFrame saved to 2018/CLE/82_04_11_2018_CLE_vs_New York Knicks.csv
# DataFrame saved to 2018/DAL/1_10_18_2017_DAL_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/DAL/2_10_20_2017_DAL_vs_Sacramento Kings.csv
# DataFrame saved to 2018/DAL/3_10_21_2017_DAL_vs_Houston Rockets.csv
# DataFrame saved to 2018/DAL/4_10_23_2017_DAL_vs_Golden State Warriors.csv
# DataFrame saved to 2018/DAL/5_10_25_2017_DAL_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/DAL/6_10_26_2017_DAL_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/DAL/7_10_28_2017_DAL_vs_Philadelphia 76ers.csv
# DataFrame saved to 2018/DAL/8_10_30_2017_DAL_vs_Utah Jazz.csv
# DataFrame saved to 2018/DAL/9_11_01_2017_DAL_vs_Los Angeles Clippers.csv
# DataFrame saved to 2018/DAL/10_11_03_2017_DAL_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/DAL/11_11_04_2017_DAL_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2018/DAL/12_11_07_2017_DAL_vs_Washington Wizards.csv
# DataFrame saved to 2018/DAL/13_11_11_2017_DAL_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/DAL/14_11_12_2017_DAL_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018/DAL/15_11_14_2017_DAL_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/DAL/16_11_17_2017_DAL_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2018/DAL/17_11_18_2017_DAL_vs_Milwaukee Bucks.csv
# DataFrame saved to 2018/DAL/18_11_20_2017_DAL_vs_Boston Celtics.csv
# DataFrame saved to 2018/DAL/19_11_22_2017_DAL_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/DAL/20_11_25_2017_DAL_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018/DAL/21_11_27_2017_DAL_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/DAL/22_11_29_2017_DAL_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/DAL/23_12_02_2017_DAL_vs_Los Angeles Clippers.csv
# DataFrame saved to 2018/DAL/24_12_04_2017_DAL_vs_Denver Nuggets.csv
# DataFrame saved to 2018/DAL/25_12_06_2017_DAL_vs_Boston Celtics.csv
# DataFrame saved to 2018/DAL/26_12_08_2017_DAL_vs_Milwaukee Bucks.csv
# DataFrame saved to 2018/DAL/27_12_10_2017_DAL_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2018/DAL/28_12_12_2017_DAL_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/DAL/29_12_14_2017_DAL_vs_Golden State Warriors.csv
# DataFrame saved to 2018/DAL/30_12_16_2017_DAL_vs_San Antonio Spurs.csv
# DataFrame saved to 2018/DAL/31_12_18_2017_DAL_vs_Phoenix Suns.csv
# DataFrame saved to 2018/DAL/32_12_20_2017_DAL_vs_Detroit Pistons.csv
# DataFrame saved to 2018/DAL/33_12_22_2017_DAL_vs_Miami Heat.csv
# DataFrame saved to 2018/DAL/34_12_23_2017_DAL_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/DAL/35_12_26_2017_DAL_vs_Toronto Raptors.csv
# DataFrame saved to 2018/DAL/36_12_27_2017_DAL_vs_Indiana Pacers.csv
# DataFrame saved to 2018/DAL/37_12_29_2017_DAL_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/DAL/38_12_31_2017_DAL_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018/DAL/39_01_03_2018_DAL_vs_Golden State Warriors.csv
# DataFrame saved to 2018/DAL/40_01_05_2018_DAL_vs_Chicago Bulls.csv
# DataFrame saved to 2018/DAL/41_01_07_2018_DAL_vs_New York Knicks.csv
# DataFrame saved to 2018/DAL/42_01_09_2018_DAL_vs_Orlando Magic.csv
# DataFrame saved to 2018/DAL/43_01_10_2018_DAL_vs_Charlotte Hornets.csv
# DataFrame saved to 2018/DAL/44_01_13_2018_DAL_vs_Los Angeles Lakers.csv
# DataFrame saved to 2018/DAL/45_01_16_2018_DAL_vs_Denver Nuggets.csv
# DataFrame saved to 2018/DAL/46_01_20_2018_DAL_vs_Portland Trail Blazers.csv
# DataFrame saved to 2018/DAL/47_01_22_2018_DAL_vs_Washington Wizards.csv
# DataFrame saved to 2018/DAL/48_01_24_2018_DAL_vs_Houston Rockets.csv
# DataFrame saved to 2018/DAL/49_01_26_2018_DAL_vs_Portland Trail Blazers.csv
# DataFrame saved to 2018/DAL/50_01_27_2018_DAL_vs_Denver Nuggets.csv
# DataFrame saved to 2018/DAL/51_01_29_2018_DAL_vs_Miami Heat.csv
# DataFrame saved to 2018/DAL/52_01_31_2018_DAL_vs_Phoenix Suns.csv
# DataFrame saved to 2018/DAL/53_02_03_2018_DAL_vs_Sacramento Kings.csv
# DataFrame saved to 2018/DAL/54_02_05_2018_DAL_vs_Los Angeles Clippers.csv
# DataFrame saved to 2018/DAL/55_02_08_2018_DAL_vs_Golden State Warriors.csv
# DataFrame saved to 2018/DAL/56_02_10_2018_DAL_vs_Los Angeles Lakers.csv
# DataFrame saved to 2018/DAL/57_02_11_2018_DAL_vs_Houston Rockets.csv
# DataFrame saved to 2018/DAL/58_02_13_2018_DAL_vs_Sacramento Kings.csv
# DataFrame saved to 2018/DAL/59_02_23_2018_DAL_vs_Los Angeles Lakers.csv
# DataFrame saved to 2018/DAL/60_02_24_2018_DAL_vs_Utah Jazz.csv
# DataFrame saved to 2018/DAL/61_02_26_2018_DAL_vs_Indiana Pacers.csv
# DataFrame saved to 2018/DAL/62_02_28_2018_DAL_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2018/DAL/63_03_02_2018_DAL_vs_Chicago Bulls.csv
# DataFrame saved to 2018/DAL/64_03_04_2018_DAL_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/DAL/65_03_06_2018_DAL_vs_Denver Nuggets.csv
# DataFrame saved to 2018/DAL/66_03_10_2018_DAL_vs_Memphis Grizzlies.csv
# DataFrame saved to 2018/DAL/67_03_11_2018_DAL_vs_Houston Rockets.csv
# DataFrame saved to 2018/DAL/68_03_13_2018_DAL_vs_New York Knicks.csv
# DataFrame saved to 2018/DAL/69_03_16_2018_DAL_vs_Toronto Raptors.csv
# DataFrame saved to 2018/DAL/70_03_17_2018_DAL_vs_Brooklyn Nets.csv
# DataFrame saved to 2018/DAL/71_03_20_2018_DAL_vs_New Orleans Pelicans.csv
# DataFrame saved to 2018/DAL/72_03_22_2018_DAL_vs_Utah Jazz.csv
# DataFrame saved to 2018/DAL/73_03_24_2018_DAL_vs_Charlotte Hornets.csv
# DataFrame saved to 2018/DAL/74_03_27_2018_DAL_vs_Sacramento Kings.csv
# DataFrame saved to 2018/DAL/75_03_28_2018_DAL_vs_Los Angeles Lakers.csv
# DataFrame saved to 2018/DAL/76_03_30_2018_DAL_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2018/DAL/77_04_01_2018_DAL_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2018/DAL/78_04_03_2018_DAL_vs_Portland Trail Blazers.csv
# DataFrame saved to 2018/DAL/79_04_04_2018_DAL_vs_Orlando Magic.csv
# DataFrame saved to 2018/DAL/80_04_06_2018_DAL_vs_Detroit Pistons.csv
# DataFrame saved to 2018/DAL/81_04_08_2018_DAL_vs_Philadelphia 76ers.csv
# DataFrame saved to 2018/DAL/82_04_10_2018_DAL_vs_Phoenix Suns.csv
# DataFrame saved to 2018/DEN/1_10_18_2017_DEN_vs_Utah Jazz.csv
# DataFrame saved to 2018/DEN/2_10_21_2017_DEN_vs_Sacramento Kings.csv
# DataFrame saved to 2018/DEN/3_10_23_2017_DEN_vs_Washington Wizards.csv
# DataFrame saved to 2018/DEN/4_10_25_2017_DEN_vs_Charlotte Hornets.csv
# DataFrame saved to 2018/DEN/5_10_27_2017_DEN_vs_Atlanta Hawks.csv
# DataFrame saved to 2018/DEN/6_10_29_2017_DEN_vs_Brooklyn Nets.csv
# DataFrame saved to 2018
vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/TOR/34_01_03_2024_TOR_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/TOR/35_01_05_2024_TOR_vs_Sacramento Kings.csv
# DataFrame saved to 2024/TOR/36_01_07_2024_TOR_vs_Golden State Warriors.csv
# DataFrame saved to 2024/TOR/37_01_09_2024_TOR_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/TOR/38_01_10_2024_TOR_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/TOR/39_01_12_2024_TOR_vs_Utah Jazz.csv
# DataFrame saved to 2024/TOR/40_01_15_2024_TOR_vs_Boston Celtics.csv
# DataFrame saved to 2024/TOR/41_01_17_2024_TOR_vs_Miami Heat.csv
# DataFrame saved to 2024/TOR/42_01_18_2024_TOR_vs_Chicago Bulls.csv
# DataFrame saved to 2024/TOR/43_01_20_2024_TOR_vs_New York Knicks.csv
# DataFrame saved to 2024/TOR/44_01_22_2024_TOR_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/TOR/45_01_26_2024_TOR_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/TOR/46_01_28_2024_TOR_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/TOR/47_01_30_2024_TOR_vs_Chicago Bulls.csv
# DataFrame saved to 2024/TOR/48_02_02_2024_TOR_vs_Houston Rockets.csv
# DataFrame saved to 2024/TOR/49_02_04_2024_TOR_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/TOR/50_02_05_2024_TOR_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/TOR/51_02_07_2024_TOR_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/TOR/52_02_09_2024_TOR_vs_Houston Rockets.csv
# DataFrame saved to 2024/TOR/53_02_10_2024_TOR_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/TOR/54_02_12_2024_TOR_vs_San Antonio Spurs.csv
# DataFrame saved to 2024/TOR/55_02_14_2024_TOR_vs_Indiana Pacers.csv
# DataFrame saved to 2024/TOR/56_02_22_2024_TOR_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/TOR/57_02_23_2024_TOR_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/TOR/58_02_26_2024_TOR_vs_Indiana Pacers.csv
# DataFrame saved to 2024/TOR/59_02_28_2024_TOR_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/TOR/60_03_01_2024_TOR_vs_Golden State Warriors.csv
# DataFrame saved to 2024/TOR/61_03_03_2024_TOR_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/TOR/62_03_05_2024_TOR_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/TOR/63_03_07_2024_TOR_vs_Phoenix Suns.csv
# DataFrame saved to 2024/TOR/64_03_09_2024_TOR_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/TOR/65_03_11_2024_TOR_vs_Denver Nuggets.csv
# DataFrame saved to 2024/TOR/66_03_13_2024_TOR_vs_Detroit Pistons.csv
# DataFrame saved to 2024/TOR/67_03_15_2024_TOR_vs_Orlando Magic.csv
# DataFrame saved to 2024/TOR/68_03_17_2024_TOR_vs_Orlando Magic.csv
# DataFrame saved to 2024/TOR/69_03_20_2024_TOR_vs_Sacramento Kings.csv
# DataFrame saved to 2024/TOR/70_03_22_2024_TOR_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/TOR/71_03_23_2024_TOR_vs_Washington Wizards.csv
# DataFrame saved to 2024/TOR/72_03_25_2024_TOR_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/TOR/73_03_27_2024_TOR_vs_New York Knicks.csv
# DataFrame saved to 2024/TOR/74_03_31_2024_TOR_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/TOR/75_04_02_2024_TOR_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/TOR/76_04_03_2024_TOR_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/TOR/77_04_05_2024_TOR_vs_Milwaukee Bucks.csv
# DataFrame saved to 2024/TOR/78_04_07_2024_TOR_vs_Washington Wizards.csv
# DataFrame saved to 2024/TOR/79_04_09_2024_TOR_vs_Indiana Pacers.csv
# DataFrame saved to 2024/TOR/80_04_10_2024_TOR_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/TOR/81_04_12_2024_TOR_vs_Miami Heat.csv
# DataFrame saved to 2024/TOR/82_04_14_2024_TOR_vs_Miami Heat.csv
# DataFrame saved to 2024/UTA/1_10_25_2023_UTA_vs_Sacramento Kings.csv
# DataFrame saved to 2024/UTA/2_10_27_2023_UTA_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/UTA/3_10_28_2023_UTA_vs_Phoenix Suns.csv
# DataFrame saved to 2024/UTA/4_10_30_2023_UTA_vs_Denver Nuggets.csv
# DataFrame saved to 2024/UTA/5_11_01_2023_UTA_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/UTA/6_11_02_2023_UTA_vs_Orlando Magic.csv
# DataFrame saved to 2024/UTA/7_11_04_2023_UTA_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/UTA/8_11_06_2023_UTA_vs_Chicago Bulls.csv
# DataFrame saved to 2024/UTA/9_11_08_2023_UTA_vs_Indiana Pacers.csv
# DataFrame saved to 2024/UTA/10_11_10_2023_UTA_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/UTA/11_11_14_2023_UTA_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/UTA/12_11_17_2023_UTA_vs_Phoenix Suns.csv
# DataFrame saved to 2024/UTA/13_11_19_2023_UTA_vs_Phoenix Suns.csv
# DataFrame saved to 2024/UTA/14_11_21_2023_UTA_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/UTA/15_11_22_2023_UTA_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/UTA/16_11_25_2023_UTA_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/UTA/17_11_27_2023_UTA_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/UTA/18_11_29_2023_UTA_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/UTA/19_11_30_2023_UTA_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/UTA/20_12_02_2023_UTA_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/UTA/21_12_06_2023_UTA_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/UTA/22_12_08_2023_UTA_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/UTA/23_12_11_2023_UTA_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/UTA/24_12_13_2023_UTA_vs_New York Knicks.csv
# DataFrame saved to 2024/UTA/25_12_14_2023_UTA_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/UTA/26_12_16_2023_UTA_vs_Sacramento Kings.csv
# DataFrame saved to 2024/UTA/27_12_18_2023_UTA_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/UTA/28_12_20_2023_UTA_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/UTA/29_12_21_2023_UTA_vs_Detroit Pistons.csv
# DataFrame saved to 2024/UTA/30_12_23_2023_UTA_vs_Toronto Raptors.csv
# DataFrame saved to 2024/UTA/31_12_26_2023_UTA_vs_San Antonio Spurs.csv
# DataFrame saved to 2024/UTA/32_12_28_2023_UTA_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/UTA/33_12_30_2023_UTA_vs_Miami Heat.csv
# DataFrame saved to 2024/UTA/34_01_01_2024_UTA_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/UTA/35_01_03_2024_UTA_vs_Detroit Pistons.csv
# DataFrame saved to 2024/UTA/36_01_05_2024_UTA_vs_Boston Celtics.csv
# DataFrame saved to 2024/UTA/37_01_06_2024_UTA_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/UTA/38_01_08_2024_UTA_vs_Milwaukee Bucks.csv
# DataFrame saved to 2024/UTA/39_01_10_2024_UTA_vs_Denver Nuggets.csv
# DataFrame saved to 2024/UTA/40_01_12_2024_UTA_vs_Toronto Raptors.csv
# DataFrame saved to 2024/UTA/41_01_13_2024_UTA_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/UTA/42_01_15_2024_UTA_vs_Indiana Pacers.csv
# DataFrame saved to 2024/UTA/43_01_18_2024_UTA_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/UTA/44_01_20_2024_UTA_vs_Houston Rockets.csv
# DataFrame saved to 2024/UTA/45_01_23_2024_UTA_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/UTA/46_01_25_2024_UTA_vs_Washington Wizards.csv
# DataFrame saved to 2024/UTA/47_01_27_2024_UTA_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/UTA/48_01_29_2024_UTA_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/UTA/49_01_30_2024_UTA_vs_New York Knicks.csv
# DataFrame saved to 2024/UTA/50_02_01_2024_UTA_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/UTA/51_02_04_2024_UTA_vs_Milwaukee Bucks.csv
# DataFrame saved to 2024/UTA/52_02_06_2024_UTA_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/UTA/53_02_08_2024_UTA_vs_Phoenix Suns.csv
# DataFrame saved to 2024/UTA/54_02_12_2024_UTA_vs_Golden State Warriors.csv
# DataFrame saved to 2024/UTA/55_02_14_2024_UTA_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/UTA/56_02_15_2024_UTA_vs_Golden State Warriors.csv
# DataFrame saved to 2024/UTA/57_02_22_2024_UTA_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/UTA/58_02_25_2024_UTA_vs_San Antonio Spurs.csv
# DataFrame saved to 2024/UTA/59_02_27_2024_UTA_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/UTA/60_02_29_2024_UTA_vs_Orlando Magic.csv
# DataFrame saved to 2024/UTA/61_03_02_2024_UTA_vs_Miami Heat.csv
# DataFrame saved to 2024/UTA/62_03_04_2024_UTA_vs_Washington Wizards.csv
# DataFrame saved to 2024/UTA/63_03_06_2024_UTA_vs_Chicago Bulls.csv
# DataFrame saved to 2024/UTA/64_03_09_2024_UTA_vs_Denver Nuggets.csv
# DataFrame saved to 2024/UTA/65_03_12_2024_UTA_vs_Boston Celtics.csv
# DataFrame saved to 2024/UTA/66_03_15_2024_UTA_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/UTA/67_03_16_2024_UTA_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/UTA/68_03_18_2024_UTA_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/UTA/69_03_20_2024_UTA_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/UTA/70_03_21_2024_UTA_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/UTA/71_03_23_2024_UTA_vs_Houston Rockets.csv
# DataFrame saved to 2024/UTA/72_03_25_2024_UTA_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/UTA/73_03_27_2024_UTA_vs_San Antonio Spurs.csv
# DataFrame saved to 2024/UTA/74_03_29_2024_UTA_vs_Houston Rockets.csv
# DataFrame saved to 2024/UTA/75_03_31_2024_UTA_vs_Sacramento Kings.csv
# DataFrame saved to 2024/UTA/76_04_02_2024_UTA_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/UTA/77_04_05_2024_UTA_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/UTA/78_04_07_2024_UTA_vs_Golden State Warriors.csv
# DataFrame saved to 2024/UTA/79_04_09_2024_UTA_vs_Denver Nuggets.csv
# DataFrame saved to 2024/UTA/80_04_11_2024_UTA_vs_Houston Rockets.csv
# DataFrame saved to 2024/UTA/81_04_12_2024_UTA_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/UTA/82_04_14_2024_UTA_vs_Golden State Warriors.csv
# DataFrame saved to 2024/WAS/1_10_25_2023_WAS_vs_Indiana Pacers.csv
# DataFrame saved to 2024/WAS/2_10_28_2023_WAS_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/WAS/3_10_30_2023_WAS_vs_Boston Celtics.csv
# DataFrame saved to 2024/WAS/4_11_01_2023_WAS_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/WAS/5_11_03_2023_WAS_vs_Miami Heat.csv
# DataFrame saved to 2024/WAS/6_11_06_2023_WAS_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/WAS/7_11_08_2023_WAS_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/WAS/8_11_10_2023_WAS_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/WAS/9_11_12_2023_WAS_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/WAS/10_11_13_2023_WAS_vs_Toronto Raptors.csv
# DataFrame saved to 2024/WAS/11_11_15_2023_WAS_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/WAS/12_11_17_2023_WAS_vs_New York Knicks.csv
# DataFrame saved to 2024/WAS/13_11_20_2023_WAS_vs_Milwaukee Bucks.csv
# DataFrame saved to 2024/WAS/14_11_22_2023_WAS_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/WAS/15_11_24_2023_WAS_vs_Milwaukee Bucks.csv
# DataFrame saved to 2024/WAS/16_11_25_2023_WAS_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/WAS/17_11_27_2023_WAS_vs_Detroit Pistons.csv
# DataFrame saved to 2024/WAS/18_11_29_2023_WAS_vs_Orlando Magic.csv
# DataFrame saved to 2024/WAS/19_12_01_2023_WAS_vs_Orlando Magic.csv
# DataFrame saved to 2024/WAS/20_12_06_2023_WAS_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/WAS/21_12_08_2023_WAS_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/WAS/22_12_11_2023_WAS_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/WAS/23_12_13_2023_WAS_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/WAS/24_12_15_2023_WAS_vs_Indiana Pacers.csv
# DataFrame saved to 2024/WAS/25_12_17_2023_WAS_vs_Phoenix Suns.csv
# DataFrame saved to 2024/WAS/26_12_18_2023_WAS_vs_Sacramento Kings.csv
# DataFrame saved to 2024/WAS/27_12_21_2023_WAS_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/WAS/28_12_22_2023_WAS_vs_Golden State Warriors.csv
# DataFrame saved to 2024/WAS/29_12_26_2023_WAS_vs_Orlando Magic.csv
# DataFrame saved to 2024/WAS/30_12_27_2023_WAS_vs_Toronto Raptors.csv
# DataFrame saved to 2024/WAS/31_12_29_2023_WAS_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/WAS/32_12_31_2023_WAS_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/WAS/33_01_03_2024_WAS_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/WAS/34_01_05_2024_WAS_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/WAS/35_01_06_2024_WAS_vs_New York Knicks.csv
# DataFrame saved to 2024/WAS/36_01_08_2024_WAS_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/WAS/37_01_10_2024_WAS_vs_Indiana Pacers.csv
# DataFrame saved to 2024/WAS/38_01_13_2024_WAS_vs_Atlanta Hawks.csv
# DataFrame saved to 2024/WAS/39_01_15_2024_WAS_vs_Detroit Pistons.csv
# DataFrame saved to 2024/WAS/40_01_18_2024_WAS_vs_New York Knicks.csv
# DataFrame saved to 2024/WAS/41_01_20_2024_WAS_vs_San Antonio Spurs.csv
# DataFrame saved to 2024/WAS/42_01_21_2024_WAS_vs_Denver Nuggets.csv
# DataFrame saved to 2024/WAS/43_01_24_2024_WAS_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/WAS/44_01_25_2024_WAS_vs_Utah Jazz.csv
# DataFrame saved to 2024/WAS/45_01_27_2024_WAS_vs_Detroit Pistons.csv
# DataFrame saved to 2024/WAS/46_01_29_2024_WAS_vs_San Antonio Spurs.csv
# DataFrame saved to 2024/WAS/47_01_31_2024_WAS_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/WAS/48_02_02_2024_WAS_vs_Miami Heat.csv
# DataFrame saved to 2024/WAS/49_02_04_2024_WAS_vs_Phoenix Suns.csv
# DataFrame saved to 2024/WAS/50_02_07_2024_WAS_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/WAS/51_02_09_2024_WAS_vs_Boston Celtics.csv
# DataFrame saved to 2024/WAS/52_02_10_2024_WAS_vs_Philadelphia 76ers.csv
# DataFrame saved to 2024/WAS/53_02_12_2024_WAS_vs_Dallas Mavericks.csv
# DataFrame saved to 2024/WAS/54_02_14_2024_WAS_vs_New Orleans Pelicans.csv
# DataFrame saved to 2024/WAS/55_02_22_2024_WAS_vs_Denver Nuggets.csv
# DataFrame saved to 2024/WAS/56_02_23_2024_WAS_vs_Oklahoma City Thunder.csv
# DataFrame saved to 2024/WAS/57_02_25_2024_WAS_vs_Cleveland Cavaliers.csv
# DataFrame saved to 2024/WAS/58_02_27_2024_WAS_vs_Golden State Warriors.csv
# DataFrame saved to 2024/WAS/59_02_29_2024_WAS_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/WAS/60_03_01_2024_WAS_vs_Los Angeles Clippers.csv
# DataFrame saved to 2024/WAS/61_03_04_2024_WAS_vs_Utah Jazz.csv
# DataFrame saved to 2024/WAS/62_03_06_2024_WAS_vs_Orlando Magic.csv
# DataFrame saved to 2024/WAS/63_03_08_2024_WAS_vs_Charlotte Hornets.csv
# DataFrame saved to 2024/WAS/64_03_10_2024_WAS_vs_Miami Heat.csv
# DataFrame saved to 2024/WAS/65_03_12_2024_WAS_vs_Memphis Grizzlies.csv
# DataFrame saved to 2024/WAS/66_03_14_2024_WAS_vs_Houston Rockets.csv
# DataFrame saved to 2024/WAS/67_03_16_2024_WAS_vs_Chicago Bulls.csv
# DataFrame saved to 2024/WAS/68_03_17_2024_WAS_vs_Boston Celtics.csv
# DataFrame saved to 2024/WAS/69_03_19_2024_WAS_vs_Houston Rockets.csv
# DataFrame saved to 2024/WAS/70_03_21_2024_WAS_vs_Sacramento Kings.csv
# DataFrame saved to 2024/WAS/71_03_23_2024_WAS_vs_Toronto Raptors.csv
# DataFrame saved to 2024/WAS/72_03_25_2024_WAS_vs_Chicago Bulls.csv
# DataFrame saved to 2024/WAS/73_03_27_2024_WAS_vs_Brooklyn Nets.csv
# DataFrame saved to 2024/WAS/74_03_29_2024_WAS_vs_Detroit Pistons.csv
# DataFrame saved to 2024/WAS/75_03_31_2024_WAS_vs_Miami Heat.csv
# DataFrame saved to 2024/WAS/76_04_02_2024_WAS_vs_Milwaukee Bucks.csv
# DataFrame saved to 2024/WAS/77_04_03_2024_WAS_vs_Los Angeles Lakers.csv
# DataFrame saved to 2024/WAS/78_04_05_2024_WAS_vs_Portland Trail Blazers.csv
# DataFrame saved to 2024/WAS/79_04_07_2024_WAS_vs_Toronto Raptors.csv
# DataFrame saved to 2024/WAS/80_04_09_2024_WAS_vs_Minnesota Timberwolves.csv
# DataFrame saved to 2024/WAS/81_04_12_2024_WAS_vs_Chicago Bulls.csv
# DataFrame saved to 2024/WAS/82_04_14_2024_WAS_vs_Boston Celtics.csv
